# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/abhay/Desktop/Probation/Probation-Project-25/Abhay_Pratap_Singh_Task_8/AdultIncome - Sheet1.csv')

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'race', 'sex', 'capital_gain',
#        'capital_loss', 'hours_per_week', 'native_country', 'income'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#        age  workclass  fnlwgt     education  education.num  \
# 21564   25  Local-gov  366796     Bachelors             13
# 26105   45          ?  215943       HS-grad              9
# 16513   30    Private   29522  Some-college             10
# 31473   31    Private   59083       HS-grad              9
# 3084    54    Private  135388       HS-grad              9
# 30002   61    Private  178312    Assoc-acdm             12
# 11616   29    Private  246974     Assoc-voc             11
# 17678   59    Private  243226          10th              6
# 18505   39  Local-gov  272166     Bachelors             13
# 21899   17    Private  147339          10th              6
#
#            marital.status         occupation   relationship   race     sex  \
# 21564       Never-married     Prof-specialty  Not-in-family  White  Female
# 26105  Married-civ-spouse                  ?        Husband  White    Male
# 16513  Married-civ-spouse              Sales           Wife  White  Female
# ...

# %%
df['education.num'].unique()
# Out:
# array([ 9, 10,  4,  6, 16, 15, 13, 14,  7, 12, 11,  2,  3,  8,  5,  1])

# %%
print(df['education'].unique())
df = df.drop(columns=['education'])
# Out:
# ['HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate' 'Prof-school'
#  'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc' '1st-4th' '5th-6th'
#  '12th' '9th' 'Preschool']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  32561 non-null  object
#  13  income          32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.columns = df.columns.str.strip().str.lower().str.replace('.', '_')

# %%
for col in df.columns:
    print(f'{col}: {df[col].unique()}')
# Out:
# age: [90 82 66 54 41 34 38 74 68 45 52 32 51 46 57 22 37 29 61 21 33 49 23 59
#  60 63 53 44 43 71 48 73 67 40 50 42 39 55 47 31 58 62 36 72 78 83 26 70
#  27 35 81 65 25 28 56 69 20 30 24 64 75 19 77 80 18 17 76 79 88 84 85 86
#  87]
# workclass: ['?' 'Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc'
#  'Local-gov' 'Without-pay' 'Never-worked']
# fnlwgt: [ 77053 132870 186061 ...  34066  84661 257302]
# education_num: [ 9 10  4  6 16 15 13 14  7 12 11  2  3  8  5  1]
# marital_status: ['Widowed' 'Divorced' 'Separated' 'Never-married' 'Married-civ-spouse'
#  'Married-spouse-absent' 'Married-AF-spouse']
# occupation: ['?' 'Exec-managerial' 'Machine-op-inspct' 'Prof-specialty'
#  'Other-service' 'Adm-clerical' 'Craft-repair' 'Transport-moving'
#  'Handlers-cleaners' 'Sales' 'Farming-fishing' 'Tech-support'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# relationship: ['Not-in-family' 'Unmarried' 'Own-child' 'Other-relative' 'Husband' 'Wife']
# ...

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].replace('?', np.nan)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].replace(np.nan, df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(8,4))
sns.countplot(x=col, data=df)
plt.title("Income Distribution")
plt.xlabel(col)
plt.ylabel("Count")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,4))
sns.histplot(df["age"], bins=30, kde=True, color="C0")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(x=col, y="hours_per_week", data=df)
plt.title("Hours per Week by Income")
plt.xlabel(col)
plt.ylabel("Hours per Week")
plt.tight_layout()
plt.show()

num_cols = df.select_dtypes(include=["number"]).columns
corr = df[num_cols].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Matrix (numeric features)")
plt.tight_layout()
plt.show()

top_occ = df["occupation"].value_counts().index[:10]
plt.figure(figsize=(10,6))
sns.countplot(y="occupation", hue=col, data=df[df["occupation"].isin(top_occ)],
              order=top_occ)
plt.title("Top 10 Occupations by Income")
plt.xlabel("Count")
plt.ylabel("Occupation")
plt.tight_layout()
plt.show()

# %%
x = df.drop(columns=['income'])
y = df['income']

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer(transformers=[
    ('onehot', OneHotEncoder(drop='first', sparse_output=False),
     x.select_dtypes(include=['object']).columns),
    ('scaler', StandardScaler(),
     x.select_dtypes(include=['number']).columns)
], remainder='passthrough')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=7)
model.fit(ct.fit_transform(X_train), y_train)
# Out:
# RandomForestClassifier(random_state=7)

# %%
import pickle
with open('income_classifier_model.pkl', 'wb') as f:
    pickle.dump((ct, model), f)
