# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('EDA .csv')
dfs = df.copy()
dfi = df.copy()

# %%
df
# Out:
#                 Crop  Crop_Year      Season              State      Area  \
# 0           Arecanut       1997  Whole Year              Assam   73814.0
# 1          Arhar/Tur       1997      Kharif              Assam    6637.0
# 2        Castor seed       1997      Kharif              Assam     796.0
# 3            Coconut       1997  Whole Year              Assam   19656.0
# 4       Cotton(lint)       1997      Kharif              Assam    1739.0
# ...              ...        ...         ...                ...       ...
# 19684  Small millets       1998      Kharif           Nagaland    4000.0
# 19685          Wheat       1998        Rabi           Nagaland    1000.0
# 19686          Maize       1997      Kharif  Jammu and Kashmir  310883.0
# 19687           Rice       1997      Kharif  Jammu and Kashmir  275746.0
# 19688          Wheat       1997        Rabi  Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# ...

# %%
for col in ['Crop_Year', 'Season', 'State']:
    print(df[col].unique())
# Out:
# [1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010
#  2011 2012 2013 2014 2015 2016 2017 2018 2019 2020]
# ['Whole Year' 'Kharif' 'Rabi' 'Autumn' 'Summer' 'Winter']
# ['Assam' 'Karnataka' 'Kerala' 'Meghalaya' 'West Bengal' 'Puducherry' 'Goa'
#  'Andhra Pradesh' 'Tamil Nadu' 'Odisha' 'Bihar' 'Gujarat' 'Madhya Pradesh'
#  'Maharashtra' 'Mizoram' 'Punjab' 'Uttar Pradesh' 'Haryana'
#  'Himachal Pradesh' 'Tripura' 'Nagaland' 'Chhattisgarh' 'Uttarakhand'
#  'Jharkhand' 'Delhi' 'Manipur' 'Jammu and Kashmir' 'Telangana'
#  'Arunachal Pradesh' 'Sikkim']

# %%
num_cols = ["Area", "Production", "Annual_Rainfall", "Fertilizer", "Pesticide", "Yield"]
for col in num_cols:
    plt.figure(figsize=(16,5))
    plt.hist(df[col], bins=500, color="skyblue", edgecolor="black")
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel('Count')

# %%
for col in num_cols:
    plt.figure(figsize=(16,2))
    plt.boxplot(df[col], vert=False)
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %%
for col in num_cols:
    plt.figure(figsize=(10,6))
    plt.scatter(df[col], df["Yield"], alpha=0.5)
    plt.title(f"Scatter plot of {col} vs Yield")
    plt.xlabel(col)
    plt.ylabel("Yield")
    plt.show()
    
crop_yield = df.groupby("Crop")["Yield"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(crop_yield.index, crop_yield.values, color="green")
plt.title("Top 15 Crops by Average Yield")
plt.xlabel("Average Yield")
plt.ylabel("Crop")
plt.gca().invert_yaxis()
plt.show()

# State-wise total production (top 15)
state_prod = df.groupby("State")["Production"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(state_prod.index, state_prod.values, color="orange")
plt.title("Top 15 States by Total Production")
plt.xlabel("Total Production")
plt.ylabel("State")
plt.gca().invert_yaxis()
plt.show()

# Yield trend over years
year_yield = df.groupby("Crop_Year")["Yield"].sum()
plt.figure(figsize=(10,6))
plt.plot(year_yield.index, year_yield.values, marker="o", color="blue")
plt.title("Average Yield Over Years")
plt.xlabel("Year")
plt.ylabel("Average Yield")
plt.grid(True)
plt.show()

# %%
df = df[df['Crop'] != 'Coconut']

for col in num_cols:
    plt.figure(figsize=(10,6))
    plt.scatter(df[col], df["Yield"], alpha=0.5)
    plt.title(f"Scatter plot of {col} vs Yield")
    plt.xlabel(col)
    plt.ylabel("Yield")
    plt.show()

crop_yield = df.groupby("Crop")["Yield"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(crop_yield.index, crop_yield.values, color="green")
plt.title("Top 15 Crops by Average Yield")
plt.xlabel("Average Yield")
plt.ylabel("Crop")
plt.gca().invert_yaxis()
plt.show()

# State-wise total production (top 15)
state_prod = df.groupby("State")["Production"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(state_prod.index, state_prod.values, color="orange")
plt.title("Top 15 States by Total Production")
plt.xlabel("Total Production")
plt.ylabel("State")
plt.gca().invert_yaxis()
plt.show()

# Yield trend over years
year_yield = df.groupby("Crop_Year")["Yield"].sum()
plt.figure(figsize=(10,6))
plt.plot(year_yield.index, year_yield.values, marker="o", color="blue")
plt.title("Average Yield Over Years")
plt.xlabel("Year")
plt.ylabel("Average Yield")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Fertilizer"], df["Yield"], alpha=0.5, color="red")
plt.xscale("log")
plt.yscale("log")
plt.title("Fertilizer vs Yield")
plt.xlabel("Fertilizer Usage")
plt.ylabel("Yield")
plt.show()

# Rainfall vs Yield (scatter)
plt.figure(figsize=(8,6))
plt.scatter(df["Annual_Rainfall"], df["Yield"], alpha=0.5, color="purple")
plt.title("Rainfall vs Yield")
plt.xlabel("Annual Rainfall")
plt.ylabel("Yield")
plt.show()

# %%
df = df[df['Yield'] < 5]
df = df[(df['Area'] > 500) & (df['Area'] < 1000000)]

# %%
num_cols = ["Area", "Production", "Annual_Rainfall", "Fertilizer", "Pesticide", "Yield"]
for col in num_cols:
    plt.figure(figsize=(16,5))
    plt.hist(df[col], bins=500, color="skyblue", edgecolor="black")
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel('Count')

for col in num_cols:
    plt.figure(figsize=(16,2))
    plt.boxplot(df[col], vert=False)
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

for col in num_cols:
    plt.figure(figsize=(10,6))
    plt.scatter(df[col], df["Yield"], alpha=0.5)
    plt.title(f"Scatter plot of {col} vs Yield")
    plt.xlabel(col)
    plt.ylabel("Yield")
    plt.show()

crop_yield = df.groupby("Crop")["Yield"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(crop_yield.index, crop_yield.values, color="green")
plt.title("Top 15 Crops by Average Yield")
plt.xlabel("Average Yield")
plt.ylabel("Crop")
plt.gca().invert_yaxis()
plt.show()

# State-wise total production (top 15)
state_prod = df.groupby("State")["Production"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(state_prod.index, state_prod.values, color="orange")
plt.title("Top 15 States by Total Production")
plt.xlabel("Total Production")
plt.ylabel("State")
plt.gca().invert_yaxis()
plt.show()

# Yield trend over years
year_yield = df.groupby("Crop_Year")["Yield"].sum()
plt.figure(figsize=(10,6))
plt.plot(year_yield.index, year_yield.values, marker="o", color="blue")
plt.title("Average Yield Over Years")
plt.xlabel("Year")
plt.ylabel("Average Yield")
plt.grid(True)
plt.show()

# %%
from scipy import stats
import numpy as np
dfs = dfs[(np.abs(stats.zscore(dfs['Yield'])) < 3)]

# %%
for col in num_cols:
    plt.figure(figsize=(10,6))
    plt.scatter(dfs[col], dfs["Yield"], alpha=0.5)
    plt.title(f"Scatter plot of {col} vs Yield")
    plt.xlabel(col)
    plt.ylabel("Yield")
    plt.show()

crop_yield = dfs.groupby("Crop")["Yield"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(crop_yield.index, crop_yield.values, color="green")
plt.title("Top 15 Crops by Average Yield")
plt.xlabel("Average Yield")
plt.ylabel("Crop")
plt.gca().invert_yaxis()
plt.show()

# State-wise total production (top 15)
state_prod = dfs.groupby("State")["Production"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(state_prod.index, state_prod.values, color="orange")
plt.title("Top 15 States by Total Production")
plt.xlabel("Total Production")
plt.ylabel("State")
plt.gca().invert_yaxis()
plt.show()

# Yield trend over years
year_yield = dfs.groupby("Crop_Year")["Yield"].sum()
plt.figure(figsize=(10,6))
plt.plot(year_yield.index, year_yield.values, marker="o", color="blue")
plt.title("Average Yield Over Years")
plt.xlabel("Year")
plt.ylabel("Average Yield")
plt.grid(True)
plt.show()

# %%
q1 = dfi['Yield'].quantile(0.25)
q3 = dfi['Yield'].quantile(0.75)
iqr = q3 - q1
dfi = dfi[(dfi['Yield'] >= q1 - 1.5*iqr) & (df['Yield'] <= q3 + 1.5*iqr)]

# %%
for col in num_cols:
    plt.figure(figsize=(10,6))
    plt.scatter(dfi[col], dfi["Yield"], alpha=0.5)
    plt.title(f"Scatter plot of {col} vs Yield")
    plt.xlabel(col)
    plt.ylabel("Yield")
    plt.show()

crop_yield = dfi.groupby("Crop")["Yield"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(crop_yield.index, crop_yield.values, color="green")
plt.title("Top 15 Crops by Average Yield")
plt.xlabel("Average Yield")
plt.ylabel("Crop")
plt.gca().invert_yaxis()
plt.show()

# State-wise total production (top 15)
state_prod = dfi.groupby("State")["Production"].sum().sort_values(ascending=False).head(15)
plt.figure(figsize=(10,6))
plt.barh(state_prod.index, state_prod.values, color="orange")
plt.title("Top 15 States by Total Production")
plt.xlabel("Total Production")
plt.ylabel("State")
plt.gca().invert_yaxis()
plt.show()

# Yield trend over years
year_yield = dfi.groupby("Crop_Year")["Yield"].sum()
plt.figure(figsize=(10,6))
plt.plot(year_yield.index, year_yield.values, marker="o", color="blue")
plt.title("Average Yield Over Years")
plt.xlabel("Year")
plt.ylabel("Average Yield")
plt.grid(True)
plt.show()
